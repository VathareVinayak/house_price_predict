# %%
import pandas as pd     
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['ggplot'])
import seaborn as sns
from  warnings import filterwarnings
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

# %% [markdown]
# OPEN FILE

# %%
dh=pd.read_csv("D:\TechnoHacks\kc_house_data.csv")
dh.head(23)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
dh.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
dh.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Columns: 21 entries, id to sqft_lot15
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
dh.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
dh.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
dh.describe(include='all').T
# Out:
#                  count unique              top freq               mean  \
# id             21613.0    NaN              NaN  NaN  4580301520.864988
# date             21613    372  20140623T000000  142                NaN
# price          21613.0    NaN              NaN  NaN      540088.141767
# bedrooms       21613.0    NaN              NaN  NaN           3.370842
# bathrooms      21613.0    NaN              NaN  NaN           2.114757
# sqft_living    21613.0    NaN              NaN  NaN        2079.899736
# sqft_lot       21613.0    NaN              NaN  NaN       15106.967566
# floors         21613.0    NaN              NaN  NaN           1.494309
# waterfront     21613.0    NaN              NaN  NaN           0.007542
# view           21613.0    NaN              NaN  NaN           0.234303
# condition      21613.0    NaN              NaN  NaN            3.40943
# grade          21613.0    NaN              NaN  NaN           7.656873
# ...

# %%
# the size of data frame (rows,columns)
dh.shape
# Out:
# (21613, 21)

# %% [markdown]
# Data Wrangling....

# %%
# Remove the 'id' column from the DataFrame
# - 'id': The name of the column to be dropped
# - axis=1: Specifies that we're dropping a column (1 for columns, 0 for rows)
# - inplace=True: Modifies the DataFrame in place, so no need to reassign to 'dh'
dh.drop(['id'],axis=1,inplace=True)

# %%
dh.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
le=LabelEncoder() #converts none numric data in numric values
dh['date']=le.fit_transform(dh['date']) #going to apply the label encoding to this column date 
dh['date'].dtype
# Out:
# dtype('int32')

# %% [markdown]
#                             DATA ANALYSIS STARTS

# %%
#first i'm counting the number of houses which have a unique floor
dh['floors'].value_counts().to_frame()
# Out:
#         count
# floors
# 1.0     10680
# 2.0      8241
# 1.5      1910
# 3.0       613
# 2.5       161
# 3.5         8

# %%
#creating and displaying Histrogram 
dh.hist(bins=50,figsize=(15,15))
plt.show()

# %%
#determine whether houses with a waterfront view or without a waterfront view have more price outliers.
sns.boxplot(data=dh,x=dh['waterfront'],y=dh['price'])
# Out:
# c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
#determine if the feature sqft_above is negatively or positively correlated with price.

sns.regplot(data=dh,x=dh['sqft_above'],y=dh['price'])
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
corr_matrix = dh.corr()
fig, ax = plt.subplots(figsize=(18, 10))
ax = sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt=".2f",cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (20.5, -0.5)

# %%
dh.drop('price',axis=1).corrwith(dh.price).plot(kind='bar',grid=True,figsize=(10,6),title="Correlation with price ")
# Out:
# <Axes: title={'center': 'Correlation with price '}>

# %%
dh.skew()
# Out:
# date              0.147286
# price             4.024069
# bedrooms          1.974300
# bathrooms         0.511108
# sqft_living       1.471555
# sqft_lot         13.060019
# floors            0.616177
# waterfront       11.385108
# view              3.395750
# condition         1.032805
# grade             0.771103
# sqft_above        1.446664
# sqft_basement     1.577965
# yr_built         -0.469805
# yr_renovated      4.549493
# zipcode           0.405661
# lat              -0.485270
# long              0.885053
# sqft_living15     1.108181
# sqft_lot15        9.506743
# dtype: float64

# %%
# splitting data
x=dh.drop(columns='price')
y=dh['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=44)

print(f"the shape of x_train is : {x_train.shape}")
print(f'the shape of x_test is : {x_test.shape}')
print(f'the shape of y_tain is : {y_train.shape}')
print(f'the shape of y_test is {y_test.shape}')
# Out:
# the shape of x_train is : (16209, 19)
# the shape of x_test is : (5404, 19)
# the shape of y_tain is : (16209,)
# the shape of y_test is (5404,)

# %%
# RandomForestRegressor

model1=RandomForestRegressor(n_estimators=200,random_state=5,max_samples=0.9,max_features=0.80,max_depth=30)
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)

print(f'R2 Score is : {r2_score(y_test,y_pred)}')
print(f'Mae is : {mean_absolute_error(y_test,y_pred)}')

# %%
# DecisionTreeRegressor
model2=DecisionTreeRegressor()
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)


print(f'R2 Score is : {r2_score(y_test,y_pred2)}')
print(f'Mae is : {mean_absolute_error(y_test,y_pred2)}')

# %%
#LinearRegression
model3=LinearRegression()
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)

print(f'R2 Score is : {r2_score(y_test,y_pred3)}')
print(f'Mae is : {mean_absolute_error(y_test,y_pred3)}')
